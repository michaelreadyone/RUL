# %%
import numpy as np
import matplotlib.cm as cm
import pandas as pd
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from train_paper import train, train_without_noise
from tqdm.notebook import tqdm

# %% [markdown]
# ## train for model with noise net (original paper)

# %%
Rated_Capacity = 1.1
feature_size = 64
feature_num = 1
dropout = 0.0
epochs = 500
nhead = 1
hidden_dim = 16
num_layers = 3
lr = 0.001  
weight_decay = 0.0
noise_level = 0.0
alpha = 0.1
metric = 're'
seed = 0
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
K = 16

SCORE = []
for seed in tqdm(range(1)):
    print('seed:{}'.format(seed))
    score_list, _, _ = train_without_noise(Rated_Capacity=Rated_Capacity, K=K, lr=lr, feature_size=feature_size, feature_num=feature_num, hidden_dim=hidden_dim, num_layers=num_layers, 
                             nhead=nhead, weight_decay=weight_decay, epochs=epochs, seed=seed, dropout=dropout, alpha=alpha, 
                             noise_level=noise_level, metric=metric, device=device)
    print(np.array(score_list))
    print(metric + 'for this seed: {:<6.4f}'.format(np.mean(np.array(score_list))))
    for s in score_list:
        SCORE.append(s)
    print('------------------------------------------------------------------')
print(metric + ' mean: {:<6.4f}'.format(np.mean(np.array(SCORE))))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# seed:0
# name: CS2_35, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
# Net(
#   (pos): PositionalEncoding()
#   (cell): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=16, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=1, bias=True)
#   (autoencoder): Autoencoder(
#     (fc1): Linear(in_features=64, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#   )
# )
# loss per epoch: 0.5611495971679688
# loss per epoch: 0.028525980189442635
# loss per epoch: 0.23601989448070526
# loss per epoch: 0.288257896900177
# loss per epoch: 0.1579921990633011
# loss per epoch: 0.04750413820147514
# loss per epoch: 0.0449863001704216
# loss per epoch: 0.10954523831605911
# loss per epoch: 0.1479613035917282
# loss per epoch: 0.12515586614608765
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:10 | loss:0.1252 | RMSE:0.3340 | RE:1.0000
# score: [1]
# score_: [1]
# loss per epoch: 0.07195897400379181
# loss per epoch: 0.03371395543217659
# loss per epoch: 0.03285614773631096
# loss per epoch: 0.058186840265989304
# loss per epoch: 0.08005252480506897
# loss per epoch: 0.07836034148931503
# loss per epoch: 0.05643368884921074
# loss per epoch: 0.03249494358897209
# loss per epoch: 0.022880179807543755
# loss per epoch: 0.030276481062173843
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:20 | loss:0.0303 | RMSE:0.3103 | RE:1.0000
# score: [1]
# score_: [1]
# loss per epoch: 0.04372202232480049
# loss per epoch: 0.04945395886898041
# loss per epoch: 0.04246906563639641
# loss per epoch: 0.02890513278543949
# loss per epoch: 0.019101552665233612
# loss per epoch: 0.01877114176750183
# loss per epoch: 0.025111261755228043
# loss per epoch: 0.030310090631246567
# loss per epoch: 0.028847994282841682
# loss per epoch: 0.021799709647893906
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:30 | loss:0.0218 | RMSE:0.2141 | RE:1.0000
# score: [1.0]
# score_: [1]
# loss per epoch: 0.014900564216077328
# loss per epoch: 0.012982677668333054
# loss per epoch: 0.015856178477406502
# loss per epoch: 0.01909123919904232
# loss per epoch: 0.018598278984427452
# loss per epoch: 0.01439619529992342
# loss per epoch: 0.010035047307610512
# loss per epoch: 0.008726965636014938
# loss per epoch: 0.01028630044311285
# loss per epoch: 0.011765391565859318
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:40 | loss:0.0118 | RMSE:0.2513 | RE:1.0000
# score: [1.0]
# score_: [1.0]
# loss per epoch: 0.010769798420369625
# loss per epoch: 0.007832101546227932
# loss per epoch: 0.005507094785571098
# loss per epoch: 0.005428828299045563
# loss per epoch: 0.006617373321205378
# loss per epoch: 0.00683435657992959
# loss per epoch: 0.005282329395413399
# loss per epoch: 0.003382019931450486
# loss per epoch: 0.002807263284921646
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      19 for seed in tqdm(range(1)):
#      20     print('seed:{}'.format(seed))
# ---> 21     score_list, _, _ = train_without_noise(Rated_Capacity=Rated_Capacity, K=K, lr=lr, feature_size=feature_size, feature_num=feature_num, hidden_dim=hidden_dim, num_layers=num_layers,
#      22                              nhead=nhead, weight_decay=weight_decay, epochs=epochs, seed=seed, dropout=dropout, alpha=alpha,
#      23                              noise_level=noise_level, metric=metric, device=device)
#      24     print(np.array(score_list))
#      25     print(metric + 'for this seed: {:<6.4f}'.format(np.mean(np.array(score_list))))
#
# File ~/Desktop/github/RUL_mike/train_paper.py:128, in train_without_noise(Rated_Capacity, K, lr, feature_size, feature_num, hidden_dim, num_layers, nhead, dropout, epochs, weight_decay, seed, alpha, noise_level, metric, device)
#     126 x, y = torch.from_numpy(x).to(device), torch.from_numpy(y).to(device)
#     127 x = x.repeat(1, K, 1)
# --> 128 output, decode = model(x)
#     129 output = output.reshape(-1, 1)
#     130 loss = criterion(output, y)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/github/RUL_mike/model_paper.py:100, in Net.forward(self, x)
#      98 batch_size, feature_num, feature_size  = x.shape
#      99 # print(f'x.shape: {x.shape}')
# --> 100 out, decode = self.autoencoder(x)
#     101 if feature_num > 1:
#     102     out = out.reshape(batch_size, -1, feature_num)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/github/RUL_mike/model_paper.py:33, in Autoencoder.forward(self, x)
#      32 def forward(self, x):
# ---> 33     out = self.mask(x)
#      34     encode = self.encoder(out)
#      35     decode = self.decoder(encode)
#
# File ~/Desktop/github/RUL_mike/model_paper.py:25, in Autoencoder.mask(self, x)
#      24 def mask(self, x):
# ---> 25     corrupted_x = x + self.noise_level * torch.randn_like(x)
#      26     return corrupted_x
#
# KeyboardInterrupt:

# %% [markdown]
# ## train for model without noise
