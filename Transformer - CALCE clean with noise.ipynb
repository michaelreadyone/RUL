# %%
import numpy as np
import matplotlib.cm as cm
import pandas as pd
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from train_paper import train, train_without_noise
from tqdm.notebook import tqdm

# %% [markdown]
# ## train for model with noise net (original paper)

# %%
Rated_Capacity = 1.1
feature_size = 64
feature_num = 1
dropout = 0.0
epochs = 500
nhead = 1
hidden_dim = 16
num_layers = 3
lr = 0.001  
weight_decay = 0.0
noise_level = 0.0
alpha = 0.1
metric = 're'
seed = 0
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
K = 16

SCORE = []
for seed in tqdm(range(1)):
    print('seed:{}'.format(seed))
    score_list, _, _ = train(Rated_Capacity=Rated_Capacity, K=K, lr=lr, feature_size=feature_size, feature_num=feature_num, hidden_dim=hidden_dim, num_layers=num_layers, 
                             nhead=nhead, weight_decay=weight_decay, epochs=epochs, seed=seed, dropout=dropout, alpha=alpha, 
                             noise_level=noise_level, metric=metric, device=device)
    print(np.array(score_list))
    print(metric + 'for this seed: {:<6.4f}'.format(np.mean(np.array(score_list))))
    for s in score_list:
        SCORE.append(s)
    print('------------------------------------------------------------------')
print(metric + ' mean: {:<6.4f}'.format(np.mean(np.array(SCORE))))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# seed:0
# name: CS2_35, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
# Net(
#   (pos): PositionalEncoding()
#   (cell): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=16, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=1, bias=True)
#   (autoencoder): Autoencoder(
#     (fc1): Linear(in_features=64, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#   )
# )
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:10 | loss:0.1820 | RMSE:0.3320 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:20 | loss:0.0792 | RMSE:0.3095 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:30 | loss:0.0616 | RMSE:0.2134 | RE:1.0000
# score: [1.0]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:40 | loss:0.0431 | RMSE:0.2518 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:50 | loss:0.0263 | RMSE:0.2551 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:60 | loss:0.0169 | RMSE:0.2680 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:70 | loss:0.0109 | RMSE:0.2514 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:80 | loss:0.0066 | RMSE:0.2085 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:90 | loss:0.0040 | RMSE:0.1904 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:100 | loss:0.0027 | RMSE:0.1939 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:110 | loss:0.0019 | RMSE:0.2010 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:120 | loss:0.0015 | RMSE:0.1964 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:130 | loss:0.0012 | RMSE:0.1910 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:140 | loss:0.0011 | RMSE:0.1906 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:150 | loss:0.0010 | RMSE:0.1835 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:160 | loss:0.0009 | RMSE:0.1755 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 811
# epoch:170 | loss:0.0008 | RMSE:0.1596 | RE:0.4129
# score: [0.41289198606271776]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 714
# epoch:180 | loss:0.0007 | RMSE:0.1454 | RE:0.2439
# score: [0.24390243902439024]
# score_: [0.41289198606271776]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 656
# epoch:190 | loss:0.0007 | RMSE:0.1286 | RE:0.1429
# score: [0.14285714285714285]
# score_: [0.24390243902439024]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 597
# epoch:200 | loss:0.0006 | RMSE:0.1004 | RE:0.0401
# score: [0.04006968641114982]
# score_: [0.14285714285714285]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 572
# epoch:210 | loss:0.0006 | RMSE:0.0843 | RE:0.0035
# score: [0.003484320557491289]
# score_: [0.04006968641114982]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 557
# epoch:220 | loss:0.0006 | RMSE:0.0714 | RE:0.0296
# score: [0.029616724738675958]
# score_: [0.003484320557491289]
# name: CS2_36, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
# Net(
#   (pos): PositionalEncoding()
#   (cell): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=16, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=1, bias=True)
#   (autoencoder): Autoencoder(
#     (fc1): Linear(in_features=64, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#   )
# )
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: -1
# epoch:10 | loss:0.1872 | RMSE:0.4947 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 0
# epoch:20 | loss:0.1125 | RMSE:0.3476 | RE:1.0000
# score: [1.0]
# score_: [1]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 0
# epoch:30 | loss:0.0585 | RMSE:0.2895 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 23
# epoch:40 | loss:0.0506 | RMSE:0.2773 | RE:0.9603
# score: [0.9602763385146805]
# score_: [1.0]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 67
# epoch:50 | loss:0.0290 | RMSE:0.2690 | RE:0.8843
# score: [0.8842832469775475]
# score_: [0.9602763385146805]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 155
# epoch:60 | loss:0.0171 | RMSE:0.5122 | RE:0.7323
# score: [0.7322970639032815]
# score_: [0.8842832469775475]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 207
# epoch:70 | loss:0.0107 | RMSE:0.7418 | RE:0.6425
# score: [0.6424870466321243]
# score_: [0.7322970639032815]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 354
# epoch:80 | loss:0.0066 | RMSE:0.5030 | RE:0.3886
# score: [0.38860103626943004]
# score_: [0.6424870466321243]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 0
# epoch:90 | loss:0.0038 | RMSE:0.2470 | RE:1.0000
# score: [1.0]
# score_: [0.38860103626943004]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 0
# epoch:100 | loss:0.0024 | RMSE:0.2629 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 719
# epoch:110 | loss:0.0015 | RMSE:0.1935 | RE:0.2418
# score: [0.24179620034542315]
# score_: [1.0]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 601
# epoch:120 | loss:0.0011 | RMSE:0.1381 | RE:0.0380
# score: [0.037996545768566495]
# score_: [0.24179620034542315]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 813
# epoch:130 | loss:0.0008 | RMSE:0.2080 | RE:0.4041
# score: [0.40414507772020725]
# score_: [0.037996545768566495]
# name: CS2_37, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
# Net(
#   (pos): PositionalEncoding()
#   (cell): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=16, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=1, bias=True)
#   (autoencoder): Autoencoder(
#     (fc1): Linear(in_features=64, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#   )
# )
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: -1
# epoch:10 | loss:0.0747 | RMSE:0.3186 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 50
# epoch:20 | loss:0.0461 | RMSE:0.5825 | RE:0.9231
# score: [0.9230769230769231]
# score_: [1]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 78
# epoch:30 | loss:0.0323 | RMSE:1.1162 | RE:0.8800
# score: [0.88]
# score_: [0.9230769230769231]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:40 | loss:0.0174 | RMSE:0.2777 | RE:1.0000
# score: [1.0]
# score_: [0.88]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:50 | loss:0.0105 | RMSE:0.2717 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 265
# epoch:60 | loss:0.0057 | RMSE:0.6312 | RE:0.5923
# score: [0.5923076923076923]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:70 | loss:0.0036 | RMSE:0.1720 | RE:1.0000
# score: [1.0]
# score_: [0.5923076923076923]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 537
# epoch:80 | loss:0.0024 | RMSE:0.0752 | RE:0.1738
# score: [0.17384615384615384]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 651
# epoch:90 | loss:0.0018 | RMSE:0.1122 | RE:0.0015
# score: [0.0015384615384615385]
# score_: [0.17384615384615384]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 504
# epoch:100 | loss:0.0014 | RMSE:0.1001 | RE:0.2246
# score: [0.2246153846153846]
# score_: [0.0015384615384615385]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 608
# epoch:110 | loss:0.0012 | RMSE:0.0803 | RE:0.0646
# score: [0.06461538461538462]
# score_: [0.2246153846153846]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 514
# epoch:120 | loss:0.0011 | RMSE:0.1079 | RE:0.2092
# score: [0.20923076923076922]
# score_: [0.06461538461538462]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 509
# epoch:130 | loss:0.0010 | RMSE:0.1281 | RE:0.2169
# score: [0.2169230769230769]
# score_: [0.20923076923076922]
# name: CS2_38, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
# Net(
#   (pos): PositionalEncoding()
#   (cell): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#         )
#         (linear1): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=16, out_features=16, bias=True)
#         (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=1, bias=True)
#   (autoencoder): Autoencoder(
#     (fc1): Linear(in_features=64, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#   )
# )
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:10 | loss:0.0944 | RMSE:0.2098 | RE:1.0000
# score: [1.0]
# score_: [1]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 52
# epoch:20 | loss:0.0700 | RMSE:0.2063 | RE:0.9247
# score: [0.9247467438494935]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:30 | loss:0.0426 | RMSE:0.2401 | RE:1.0000
# score: [1.0]
# score_: [0.9247467438494935]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:40 | loss:0.0287 | RMSE:0.3118 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:50 | loss:0.0184 | RMSE:0.2578 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:60 | loss:0.0098 | RMSE:0.1959 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:70 | loss:0.0057 | RMSE:0.1946 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:80 | loss:0.0030 | RMSE:0.2178 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 766
# epoch:90 | loss:0.0016 | RMSE:0.1354 | RE:0.1085
# score: [0.1085383502170767]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 451
# epoch:100 | loss:0.0010 | RMSE:0.2869 | RE:0.3473
# score: [0.3473227206946454]
# score_: [0.1085383502170767]
# [[0.00348432]
#  [0.03799655]
#  [0.20923077]
#  [0.10853835]]
# refor this seed: 0.0898
# ------------------------------------------------------------------
# re mean: 0.0898

# %% [markdown]
# ## train for model without noise
