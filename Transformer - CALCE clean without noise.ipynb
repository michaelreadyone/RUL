# %%
import numpy as np
import matplotlib.cm as cm
import pandas as pd
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from train_paper import train, train_without_noise
from tqdm.notebook import tqdm

# %% [markdown]
# ## train for model with noise net (original paper)

# %%
Rated_Capacity = 1.1
feature_size = 64
feature_num = 1
dropout = 0.0
epochs = 500
nhead = 1
hidden_dim = 16
num_layers = 3
lr = 0.001  
weight_decay = 0.0
noise_level = 0.0
alpha = 0.1
metric = 're'
seed = 0
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
K = 16

SCORE = []
for seed in tqdm(range(1)):
    print('seed:{}'.format(seed))
    score_list, _, _ = train_without_noise(Rated_Capacity=Rated_Capacity, K=K, lr=lr, feature_size=feature_size, feature_num=feature_num, hidden_dim=hidden_dim, num_layers=num_layers, 
                             nhead=nhead, weight_decay=weight_decay, epochs=epochs, seed=seed, dropout=dropout, alpha=alpha, 
                             noise_level=noise_level, metric=metric, device=device)
    print(np.array(score_list))
    print(metric + 'for this seed: {:<6.4f}'.format(np.mean(np.array(score_list))))
    for s in score_list:
        SCORE.append(s)
    print('------------------------------------------------------------------')
print(metric + ' mean: {:<6.4f}'.format(np.mean(np.array(SCORE))))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# seed:0
# name: CS2_35, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:10 | loss:0.1252 | RMSE:0.3340 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: -1
# epoch:20 | loss:0.0303 | RMSE:0.3103 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:30 | loss:0.0218 | RMSE:0.2141 | RE:1.0000
# score: [1.0]
# score_: [1]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:40 | loss:0.0118 | RMSE:0.2513 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:50 | loss:0.0035 | RMSE:0.2552 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:60 | loss:0.0013 | RMSE:0.2768 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:70 | loss:0.0010 | RMSE:0.2489 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 501
# epoch:80 | loss:0.0007 | RMSE:0.0870 | RE:0.1272
# score: [0.12717770034843207]
# score_: [1.0]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 537
# epoch:90 | loss:0.0006 | RMSE:0.1256 | RE:0.0645
# score: [0.06445993031358885]
# score_: [0.12717770034843207]
#
# len(y_test): 817
# len(y_predict): 817
# threshold: 0.77
# y_test[i]: 0.7609089280745479, y_test[i+1]: 0.7609134727150945
# i: 575
# true_battery_life: 574, pred_battery_life: 0
# epoch:100 | loss:0.0005 | RMSE:0.1816 | RE:1.0000
# score: [1.0]
# score_: [0.06445993031358885]
# name: CS2_36, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: -1
# epoch:10 | loss:0.0357 | RMSE:0.2941 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 12
# epoch:20 | loss:0.0197 | RMSE:0.2736 | RE:0.9793
# score: [0.9792746113989638]
# score_: [1]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 53
# epoch:30 | loss:0.0092 | RMSE:0.2930 | RE:0.9085
# score: [0.9084628670120898]
# score_: [0.9792746113989638]
#
# len(y_test): 871
# len(y_predict): 871
# threshold: 0.77
# y_test[i]: 0.7611258502328907, y_test[i+1]: 0.7611186525259319
# i: 580
# true_battery_life: 579, pred_battery_life: 0
# epoch:40 | loss:0.0006 | RMSE:0.7095 | RE:1.0000
# score: [1.0]
# score_: [0.9084628670120898]
# name: CS2_37, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: -1
# epoch:10 | loss:0.1316 | RMSE:0.3794 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 16
# epoch:20 | loss:0.0174 | RMSE:0.2637 | RE:0.9754
# score: [0.9753846153846154]
# score_: [1]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:30 | loss:0.0184 | RMSE:0.2638 | RE:1.0000
# score: [1.0]
# score_: [0.9753846153846154]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:40 | loss:0.0052 | RMSE:0.3047 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:50 | loss:0.0010 | RMSE:0.2956 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:60 | loss:0.0008 | RMSE:0.3044 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:70 | loss:0.0008 | RMSE:0.2893 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 0
# epoch:80 | loss:0.0007 | RMSE:0.2276 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 721
# epoch:90 | loss:0.0006 | RMSE:0.1346 | RE:0.1092
# score: [0.10923076923076923]
# score_: [1.0]
#
# len(y_test): 907
# len(y_predict): 907
# threshold: 0.77
# y_test[i]: 0.7697710546328862, y_test[i+1]: 0.7610105733432071
# i: 651
# true_battery_life: 650, pred_battery_life: 506
# epoch:100 | loss:0.0005 | RMSE:0.0860 | RE:0.2215
# score: [0.22153846153846155]
# score_: [0.10923076923076923]
# name: CS2_38, feature_size: 64
# feature_size: 64, hidden_dim: 16, feature_num: 16, num_layers: 3, nhead: 1, dropout: 0.0, noise_level: 0.0
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: -1
# epoch:10 | loss:0.0792 | RMSE:0.4969 | RE:1.0000
# score: [1]
# score_: [1]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:20 | loss:0.0895 | RMSE:0.3563 | RE:1.0000
# score: [1.0]
# score_: [1]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:30 | loss:0.0271 | RMSE:0.2070 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 31
# epoch:40 | loss:0.0152 | RMSE:0.3018 | RE:0.9551
# score: [0.9551374819102749]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:50 | loss:0.0057 | RMSE:0.1894 | RE:1.0000
# score: [1.0]
# score_: [0.9551374819102749]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:60 | loss:0.0024 | RMSE:0.2361 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:70 | loss:0.0011 | RMSE:0.2687 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 0
# epoch:80 | loss:0.0008 | RMSE:0.2335 | RE:1.0000
# score: [1.0]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 369
# epoch:90 | loss:0.0005 | RMSE:0.4320 | RE:0.4660
# score: [0.46599131693198265]
# score_: [1.0]
#
# len(y_test): 931
# len(y_predict): 931
# threshold: 0.77
# y_test[i]: 0.7608392633988722, y_test[i+1]: 0.7516569834565069
# i: 692
# true_battery_life: 691, pred_battery_life: 340
# epoch:100 | loss:0.0006 | RMSE:0.4019 | RE:0.5080
# score: [0.507959479015919]
# score_: [0.46599131693198265]
# [[0.06445993]
#  [0.90846287]
#  [0.10923077]
#  [0.46599132]]
# refor this seed: 0.3870
# ------------------------------------------------------------------
# re mean: 0.3870

# %% [markdown]
# ## train for model without noise
